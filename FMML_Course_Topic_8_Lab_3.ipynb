# %% [markdown]
# <a href="https://colab.research.google.com/github/anukomma/FMML_PROJECTS_AND_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 05:18:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   185MB/s    in 0.4s
#
# 2024-03-31 05:18:12 (185 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22176  1506.07930v1  We present a technique for clustering categori...  stat
# 22849  1709.00776v1  The interpretability of prediction mechanisms ...  stat
# 1221   1512.01289v2  Judgments about personality based on facial ap...    cs
# 7419   1712.07106v2  Two-dimensional embeddings remain the dominant...  stat
# 39461  1605.07650v1  CT protocol design and quality control would b...    cs
# ...             ...                                                ...   ...
# 3183    1206.4653v1  We present local discriminative Gaussian (LDG)...    cs
# 37955   1301.3514v1  We introduce the anti-profile Support Vector M...  stat
# 2207   1706.08146v1  We propose a simple and efficient approach to ...    cs
# 9748   1612.08543v1  Big data trend has enforced the data-centric s...  stat
# 12120  1708.08022v1  The recent, remarkable growth of machine learn...  stat
#
#                                                    title  year  \
# 22176  Clustering categorical data via ensembling dis...  2015
# 22849  Estimation of interventional effects of featur...  2017
# 1221   Predicting and visualizing psychological attri...  2015
# 7419   Exploring High-Dimensional Structure via Axis-...  2017
# 39461  Blind Analysis of CT Image Noise Using Residua...  2016
# ...                                                  ...   ...
# 3183   Dimensionality Reduction by Local Discriminati...  2012
# 37955  Anomaly Classification with the Anti-Profile S...  2013
# 2207   There and Back Again: A General Approach to Le...  2017
# 9748   Distributed Real-Time Sentiment Analysis for B...  2016
# 12120  On the Protection of Private Information in Ma...  2017
#
#                                                 keywords
# 22176  [technique, clustering, categorical, generatin...
# 22849  [interpretability, prediction, mechanisms, und...
# 1221   [judgments, personality, appearance, effectors...
# 7419   [dimensional, embeddings, visualize, dimension...
# 39461  [automated, generated, erroneous, acquisitions...
# ...                                                  ...
# 3183   [discriminative, dimensionality, reduction, su...
# 37955  [introduce, algorithm, classification, extensi...
# 2207   [efficient, projecting, dimensional, dimension...
# 9748   [continuous, analytics, happening, negligible,...
# 12120  [remarkable, techniques, preserving, literatur...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22176    [technique, clustering, categorical, generatin...
# 22849    [interpretability, prediction, mechanisms, und...
# 1221     [judgments, personality, appearance, effectors...
# 7419     [dimensional, embeddings, visualize, dimension...
# 39461    [automated, generated, erroneous, acquisitions...
#                                ...
# 20618    [probabilistic, graphical, analytics, structur...
# 23203    [representation, recognition, interpretation, ...
# 2969     [statistical, classifying, cognitive, processe...
# 7051     [assortment, selection, parameters, logarithmi...
# 2463     [conditions, emergence, intelligence, interact...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8825 words.
# Out of those 4634 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f7d67569-a049-4f3b-afd4-a7284827942e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7d67569-a049-4f3b-afd4-a7284827942e")) {                    Plotly.newPlot(                        "f7d67569-a049-4f3b-afd4-a7284827942e",                        [{"x":["generating","continues","comparing","particular","clusterings","demonstrating","dissimilarity","averaging","phylogenetic","clustering","alignment","explanatory","technique","sequences","variables","categorical","dimensional","conditions","ensembling","suggested","techniques","developing","regarding","interventional","influence","demonstrated","intervention","parameters","artificial","structure","evaluated","interpretability","mechanism","underlying","restrictions","prediction","applicability","estimation","identifies","estimates","necessary","framework","considered","meaningful","mechanisms","relationships","predictors","generation","linearity","implementation","personality","demonstrate","appearance","perception","deconvolutional","visualize","landmarks","important","intelligence","elections","surpassing","predicting","approaches","increasing","effectors","performance","furthermore","visualizing","judgments","successful","attributes","psychological","convolutional","separately","presidential","memorability","annotated","efficiency","decisions","embeddings","difficult","interpret","resulting","neighborhood","introduce","interactive","directions","visualization","compromise","projection","decomposition","significantly","complexity","combinations","components","representatives","intuitive","exploring","bivariate","quantitatively","relations","projections","displayed","nevertheless","visualizations","information","integrated","interpreting","underestimate","erroneous","automated","protocols","performed","generated","methodology","investigates","filtering","acquisitions","characteristics","anisotropic","determine","conventional","algorithms","application","diffusion","corresponding","transform","frequency","implement","simulation","international","proceedings","conference","synthesis","practical","functional","estimated","unsatisfactory","applications","numerical","afterward","maximization","regressions","expectation","retrieving","selecting","likelihood","penalized","robustness","simultaneously","statistics","simulated","challenging","initialization","candidate","unsupervised","partition","developed","regression","polynomial","selection","experiments","algorithm","motivation","cognitive","theoretical","computations","introduced","personalized","quantitative","modelling","incorporates","reasoning","processes","knowledge","reusability","persuasion","attitudes","persistent","integrating","abstraction","pedagogical","architecture","employing","computational","limitations","generalized","different","pedestrian","detection","recognition","properties","classifier","impressive","architectural","relationship","benchmark","conclusions","architectures","generalize"],"y":[103,5,68,284,3,41,4,22,2,124,49,2,273,86,130,14,162,132,2,32,372,58,29,0,58,96,7,247,147,335,150,15,118,115,20,208,29,207,26,66,84,549,135,50,42,67,16,126,6,148,6,574,65,35,4,18,10,334,93,5,11,66,421,114,2,893,158,12,15,90,64,10,356,34,4,2,66,149,63,73,141,24,150,26,327,34,48,25,6,49,72,258,231,38,97,4,45,37,0,29,83,15,4,16,11,698,43,8,2,10,113,11,127,176,78,25,57,5,97,11,66,123,576,251,23,137,66,55,80,68,27,15,16,47,151,52,59,4,425,73,1,28,0,34,3,34,61,1,114,111,65,50,247,24,52,129,27,207,108,65,169,603,776,19,44,163,36,154,18,66,45,39,141,121,335,4,3,2,10,36,21,4,238,31,285,61,92,753,18,351,384,197,156,19,7,72,185,26,111,57],"type":"bar"},{"x":["generating","continues","comparing","particular","clusterings","dem ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4634,), (4634, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8266666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3478260869565217);'>Baselines</span> <span style=''>and</span> <span style=''>test</span> <span style=''>data</span> <span style=''>for</span> <span style=''>cross</span> <span style=''>lingual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <br/><br/><span style=''>The</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>have</span> <span style=''>seen</span> <span style=''>a</span> <span style=''>revival</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>textual</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>entailment</span> <span style=''>sparked</span> <span style=''>by</span> <span style=''>i)</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>emergence</span> <span style=''>of</span> <span style=''>powerful</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>learners</span> <span style=''>for</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.40703517587939697);'>processing</span> <span style=''>and</span> <span style=''>ii)</span> <span style=''>the</span> <span style=''>timely</span> <span style='background-color:rgba(0, 255, 0, 0.4576271186440678);'>development</span> <span style=''>of</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3954659949622166);'>evaluation</span> <span style=''>datasets</span> <span style=''>such</span> <span style=''>as</span> <span style=''>SNLI</span> <span style=''>Recast</span> <span style=''>as</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>now</span> <span style=''>amounts</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3928571428571428);'>detecting</span> <span style=''>the</span> <span style=''>relation</span> <span style=''>between</span> <span style=''>pairs</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>statements</span> <span style=''>they</span> <span style=''>either</span> <span style=''>contradict</span> <span style=''>or</span> <span style=''>entail</span> <span style=''>one</span> <span style=''>another</span> <span style=''>or</span> <span style=''>they</span> <span style=''>are</span> <span style=''>mutually</span> <span style=''>neutral</span> <span style=''>Current</span> <span style=''>research</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3750000000000001);'>effectively</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exclusive</span> <span style=''>to</span> <span style=''>English</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>advance</span> <span style=''>the</span> <span style=''>research</span> <span style=''>in</span> <span style=''>SNLI</span> <span style=''>style</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>toward</span> <span style='background-color:rgba(0, 255, 0, 0.92);'>multilingual</span> <span style='background-color:rgba(0, 255, 0, 0.3954659949622166);'>evaluation</span> <span style=''>To</span> <span style=''>that</span> <span style=''>end</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>test</span> <span style=''>data</span> <span style=''>for</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Ratio</span> <span style=''>Utility</span> <span style=''>and</span> <span style=''>Cost</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>Privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Preserving</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Projection</span> <br/><br/><span style=''>With</span> <span style=''>a</span> <span style=''>rapidly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>number</span> <span style=''>of</span> <span style=''>devices</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>to</span> <span style=''>the</span> <span style=''>internet</span> <span style=''>big</span> <span style=''>data</span> <span style=''>has</span> <span style=''>been</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>various</span> <span style=''>domains</span> <span style=''>of</span> <span style=''>human</span> <span style=''>life</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nevertheless</span> <span style=''>it</span> <span style=''>has</span> <span style=''>also</span> <span style=''>opened</span> <span style=''>new</span> <span style=''>venues</span> <span style=''>for</span> <span style=''>breaching</span> <span style=''>users</span> <span style=''>privacy</span> <span style=''>Hence</span> <span style=''>it</span> <span style=''>is</span> <span style=''>highly</span> <span style=''>required</span> <span style=''>to</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>that</span> <span style=''>enable</span> <span style=''>data</span> <span style=''>owners</span> <span style=''>to</span> <span style=''>privatize</span> <span style=''>their</span> <span style=''>data</span> <span style=''>while</span> <span style=''>keeping</span> <span style=''>it</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>intended</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>Existing</span> <span style=''>methods</span> <span style=''>however</span> <span style=''>do</span> <span style=''>not</span> <span style=''>offer</span> <span style=''>enough</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>controlling</span> <span style=''>the</span> <span style=''>utility</span> <span style=''>privacy</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>and</span> <span style=''>may</span> <span style=''>incur</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unfavorable</span> <span style=''>results</span> <span style=''>when</span> <span style=''>privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>are</span> <span style=''>high</span> <span style=''>To</span> <span style=''>tackle</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>drawbacks</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressive</span> <span style=''>privacy</span> <span style=''>based</span> <span style=''>method</span> <span style=''>namely</span> <span style=''>RUCA</span> <span style=''>(Ratio</span> <span style=''>Utility</span> <span style=''>and</span> <span style=''>Cost</span> <span style=''>Analysis)</span> <span style=''>which</span> <span style=''>can</span> <span style=''>not</span> <span style=''>only</span> <span style=''>maximize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>for</span> <span style=''>a</span> <span style=''>privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>insensitive</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>reducing</span> <span style=''>sampling</span> <span style=''>variance</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454544);'>covariate</span> <span style=''>shift</span> <span style=''>using</span> <span style=''>control</span> <span style=''>variates</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.4545454545454544);'>Covariate</span> <span style=''>shift</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>be</span> <span style=''>tackled</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>However</span> <span style=''>the</span> <span style=''>sampling</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.6455696202531647);'>estimator</span> <span style=''>is</span> <span style=''>often</span> <span style=''>scaled</span> <span style=''>up</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dramatically</span> <span style=''>by</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>This</span> <span style=''>means</span> <span style=''>that</span> <span style=''>during</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>risk</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>repeatedly</span> <span style='background-color:rgba(0, 255, 0, 0.38888888888888884);'>evaluated</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923077);'>suboptimal</span> <span style='background-color:rgba(255, 0, 0, 0.4857142857142857);'>hyperparameter</span> <span style='background-color:rgba(255, 0, 0, 0.32653061224489793);'>estimates</span> <span style=''>are</span> <span style=''>produced</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variances</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>versus</span> <span style=''>the</span> <span style=''>oracle</span> <span style='background-color:rgba(255, 0, 0, 0.6455696202531647);'>estimator</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>scale</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>control</span> <span style=''>variate</span> <span style=''>can</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.6455696202531647);'>estimator</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>superior</span> <span style='background-color:rgba(255, 0, 0, 0.359375);'>regul ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style=''>Training</span> <span style=''>for</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>Mixture</span> <span style=''>and</span> <span style=''>Topic</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Supervisory</span> <span style=''>signals</span> <span style=''>have</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>to</span> <span style=''>make</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>like</span> <span style=''>those</span> <span style=''>learned</span> <span style=''>by</span> <span style=''>mixture</span> <span style=''>and</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>and</span> <span style=''>useful</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>training</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>balances</span> <span style=''>two</span> <span style=''>goals</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>faithful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>and</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>semantic</span> <span style=''>labels</span> <span style=''>Existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>these</span> <span style=''>goals</span> <span style=''>due</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asymmetry</span> <span style=''>the</span> <span style=''>intended</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>is</span> <span style=''>always</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>labels</span> <span style=''>from</span> <span style=''>data</span> <span style=''>not</span> <span style=''>data</span> <span style=''>from</span> <span style=''>labels</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>for</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherently</span> <span style='back ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1206772334293948)
# 	representation (0.1260806916426513)
# 	experimental (0.13652737752161384)
# 	architecture (0.08573487031700289)
# 	segmentation (0.06988472622478387)
# 	detection (0.12644092219020173)
# 	information (0.25144092219020175)
# 	convolutional (0.1282420749279539)
# 	different (0.2712536023054755)
# 	recognition (0.138328530259366)
#
# Some Statistics words are:
# 	variables (0.12944664031620554)
# 	stochastic (0.12648221343873517)
# 	theoretical (0.1482213438735178)
# 	statistical (0.14970355731225296)
# 	distribution (0.17440711462450592)
# 	algorithm (0.38290513833992096)
# 	estimation (0.17885375494071146)
# 	inference (0.18231225296442688)
# 	dimensional (0.18033596837944665)
# 	regression (0.17885375494071146)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ccef7fec-9054-4e80-a358-7b04145bcdba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccef7fec-9054-4e80-a358-7b04145bcdba")) {                    Plotly.newPlot(                        "ccef7fec-9054-4e80-a358-7b04145bcdba",                        [{"x":["generating","continues","comparing","particular","clusterings","demonstrating","dissimilarity","averaging","phylogenetic","clustering","alignment","explanatory","technique","sequences","variables","categorical","dimensional","conditions","ensembling","suggested","techniques","developing","regarding","interventional","influence","demonstrated","intervention","parameters","artificial","structure","evaluated","interpretability","mechanism","underlying","restrictions","prediction","applicability","estimation","identifies","estimates","necessary","framework","considered","meaningful","mechanisms","relationships","predictors","generation","linearity","implementation","personality","demonstrate","appearance","perception","deconvolutional","visualize","landmarks","important","intelligence","elections","surpassing","predicting","approaches","increasing","effectors","performance","furthermore","visualizing","judgments","successful","attributes","psychological","convolutional","separately","presidential","memorability","annotated","efficiency","decisions","embeddings","difficult","interpret","resulting","neighborhood","introduce","interactive","directions","visualization","compromise","projection","decomposition","significantly","complexity","combinations","components","representatives","intuitive","exploring","bivariate","quantitatively","relations","projections","displayed","nevertheless","visualizations","information","integrated","interpreting","underestimate","erroneous","automated","protocols","performed","generated","methodology","investigates","filtering","acquisitions","characteristics","anisotropic","determine","conventional","algorithms","application","diffusion","corresponding","transform","frequency","implement","simulation","international","proceedings","conference","synthesis","practical","functional","estimated","unsatisfactory","applications","numerical","afterward","maximization","regressions","expectation","retrieving","selecting","likelihood","penalized","robustness","simultaneously","statistics","simulated","challenging","initialization","candidate","unsupervised","partition","developed","regression","polynomial","selection","experiments","algorithm","motivation","cognitive","theoretical","computations","introduced","personalized","quantitative","modelling","incorporates","reasoning","processes","knowledge","reusability","persuasion","attitudes","persistent","integrating","abstraction","pedagogical","architecture","employing","computational","limitations","generalized","different","pedestrian","detection","recognition","properties","classifier","impressive","architectural","relationship","benchmark","conclusions","architectures","generalize","operating","motivating","sensitive","situation","topologies","universal","indicators","traditional","processing","distributed","foundations","correlations","auxiliary","functions","specifically","statistical","challenges","requiring","procedure","conducted","supervised","experimental","operators","challenge","ingredient","eigenvalue","mentioned","indicator","objective","memorization","operational","representations","comparative","boundaries","replicating","memorized","organized","characterizing","synthetic","spatially","structured","understand","characterize","representational","stratifying","variation","competitive","efficiently","distribution","community","development","maintaining","modularity","communities","stabil ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	interventional
# 	bivariate
# 	regressions
# 	stratification
# 	eigendecomposition
# 	tolerates
# 	impossibility
# 	semiparametric
# 	microwave
# 	tractably
# 	physiologic
# 	inexactly
# 	complimentary
# 	itinerary
# 	macroeconomic
# 	conjugacy
# 	oblivious
# 	economists
# 	frequentist
# 	embarrassingly
# Some words which never appear in Statistics papers:
# 	personality
# 	surpassing
# 	memorability
# 	underestimate
# 	acquisitions
# 	reusability
# 	persuasion
# 	attitudes
# 	replicating
# 	subjected
# 	personnel
# 	automaton
# 	admissibility
# 	undecidability
# 	undecidable
# 	decidable
# 	dempsters
# 	listening
# 	repetitive
# 	mitigation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.086991418163858e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
